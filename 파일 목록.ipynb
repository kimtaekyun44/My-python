# %%
## 싱행 경로 변경하기
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)

# Change the current working directory
new_directory = r'C:\Users\user\OneDrive\바탕 화면\메타버스\3.논문정리\2.메타버스'  # Corrected path with raw string
os.chdir(new_directory)

# Verify the new working directory
new_directory_confirmed = os.getcwd()
print("New Working Directory:", new_directory_confirmed)
# Out:
# Current Working Directory: C:\python
# New Working Directory: C:\Users\user\OneDrive\바탕 화면\메타버스\3.논문정리\2.메타버스

# %%
# 현재 디렉토리의 모든 파일 목록 가져오기
file_list = os.listdir('.')

# 파일 이름순으로 정렬
file_list.sort()

# 파일 이름 출력
for file in file_list:
    print(file)
# Out:
# 1.Metaverse for Social Good A University Campus Prototype.pdf
# 10.메타버스의 발전방향과 활성화를 위한 6대 이슈 연구.pdf
# 11.문화 여가 중심의 메타버스 유형 및 발전 방향 연구.pdf
# 12.역사교육을 위한 메타버스 콘텐츠 연구.pdf
# 2-1.Metaverse Servicescape  Emotional Response to Virtual Retail Design ko.pdf
# 2.Metaverse Servicescape  Emotional Response to Virtual Retail Design.pdf
# 3-1.Metaverse-based_education_service_adoption_and_preference_study_using_conjoint_analysis ko.pdf
# 3.Metaverse-based_education_service_adoption_and_preference_study_using_conjoint_analysis.pdf
# 4.공공분야 메타버스의 어포던스 디자인 요소에 대한 CVR 분석 연구.pdf
# 5.메타버스 공간 내에서 게임 기획 요소가 게임 유저 간 공감 형성 및 이용에 관한 연구.pdf
# 6.메타버스 기반 교육 시스템 제고를 위한 온라인 교육의 효과 분석.pdf
# 7.메타버스 아바타의 용도별 사용 효율성에 관한 연구.pdf
# 8.메타버스를 활용한 역사과 교사교육의 가능성과 한계.pdf
# 9.메타버스의 개념과 발전 방향.pdf
