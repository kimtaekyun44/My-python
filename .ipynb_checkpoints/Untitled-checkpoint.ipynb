# %%
import pandas as pd

# Creating the data
data =   {
    "이름": ["김윤경", "장호삼", "정경아", "이미옥", "김사운"],
    "전화번호": ["010-7274-1416", "010-6642-2589", "010-7313-7013", "010-5343-5505", "010-5014-7006"],
    "주소": [
        "경기도 부천시 옥길로 55, 707동 1905호 (옥길동, 옥길센트리뷰)",
        "경기도 남양주시 진접읍 해밀예당1로 272 (신안인스빌23단지아파트) 2305동 801호",
        "강동구 고덕로 61길 37 현대아파트 101동 1203호",
        "경기도 하남시 하남대로 887번길 25(덕풍동 한솔아파트) 102동 1503호",
        "경기도 수원시 권선구 동수원로 177번길 40 (수원아이파크시티8단지)803동 206호"
    ]
}
# Creating a DataFrame
df = pd.DataFrame(data)



df
# Out:
#     이름           전화번호                                                 주소
# 0  김윤경  010-7274-1416           경기도 부천시 옥길로 55, 707동 1905호 (옥길동, 옥길센트리뷰)
# 1  장호삼  010-6642-2589  경기도 남양주시 진접읍 해밀예당1로 272 (신안인스빌23단지아파트) 2305동 801호
# 2  정경아  010-7313-7013                    강동구 고덕로 61길 37 현대아파트 101동 1203호
# 3  이미옥  010-5343-5505        경기도 하남시 하남대로 887번길 25(덕풍동 한솔아파트) 102동 1503호
# 4  김사운  010-5014-7006   경기도 수원시 권선구 동수원로 177번길 40 (수원아이파크시티8단지)803동 206호

# %%
df.to_clipboard(index=False, header=False)

# %%
import pandas as pd

# Data to be organized into a DataFrame
data = [
    ["정필오", "010-3010-1678", "경기도 용인시 기흥구 동백5로 41 성산마을 신영지웰아파트 3005동 1602호"],
    ["유제윤", "010-5182-0518", "서울 중구 을지로 55 하나은행별관빌딩 8층 에듀테크부문"],
    ["연혜진", "010-5620-9360", "인천시 계양구 계산로186 현대아파트 107동 1203호"],
    ["윤혜정", "010-2834-6579", "04513 서울특별시 중구 세종대로9길 42 부영빌딩 8층"],
    ["윤순호", "010-6396-6706", "화성시 동탄 중앙로 189 345-1702"],
    ["최철훈", "010-8630-5849", "경기도 남양주시 와부읍 덕소로 286-1 건영아파트 108동 504호"]
]

# Creating the DataFrame
df = pd.DataFrame(data, columns=["이름", "전화번호", "주소"])

# %%
df.to_clipboard(index=False, header=False)
