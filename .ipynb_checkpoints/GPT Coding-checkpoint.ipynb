# %% [markdown]
# ## 패키지 설치
# !pip install openai <P>
# !pip install -U python-dotenv <p>
# !pip install openai==0.28 --> 0.28에서만 가능

# %%
import openai
import os
from dotenv import load_dotenv, find_dotenv

# %%
_ = load_dotenv(find_dotenv())

# %%
def get_completion(prompt, model='gpt-3.5-turbo'):
    messages = [{'role': 'user', 'content': prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0  # 출력의 다양성을 조정하는 매개변수, 0이면 응답이 더 일관적
    )
    return response.choices[0].message['content']

# %%
text ='''
우리 나라의 인구를 연도별로 정리해서 알려 주세요
'''

# %%
prompt = "Explain the importance of conic sections in computer science."
response = get_completion(prompt)
print(response)
# Out:
# Conic sections are important in computer science because they are used in various mathematical algorithms and calculations. They are particularly useful in computer graphics, where they are used to represent and manipulate shapes such as circles, ellipses, parabolas, and hyperbolas.
#
# Conic sections are also used in computer-aided design (CAD) software to create and manipulate geometric shapes. They are used in algorithms for curve fitting, interpolation, and approximation, as well as in optimization problems.
#
# Additionally, conic sections are used in computer vision applications, such as object recognition and tracking. They are also used in signal processing, image processing, and data analysis.
#
# Overall, conic sections play a crucial role in computer science by providing mathematical tools and techniques for solving a wide range of problems in various fields of study.

# %%
# !pip show openai

# %%
# !pip uninstall openai
