# %%
import pandas as pd , numpy as np

# %%
df = pd.read_csv("Class_data3.csv" , encoding="euc-kr")

# %%
df
# Out:
#      메타버스장점1  메타버스장점2  메타버스장점3  메타버스극복1  메타버스극복2  메타버스극복3  메타버스비활성화이유  \
# 0          1        4        5        4        5        6           2
# 1          4        2        5        2        4        5           2
# 2          2        5        3        2        5        4           2
# 3          1        3        4        2        1        4           2
# 4          1        3        4        4        6        5           3
# ..       ...      ...      ...      ...      ...      ...         ...
# 495        1        3        4        3        2        4           2
# 496        3        2        5        2        1        3           3
# 497        1        4        3        1        2        5           1
# 498        1        5        2        3        2        4           4
# 499        5        3        6        2        3        4           2
#
#      메타버스부정적기능  메타버스입장  Class
# 0            2       3      1
# 1            3       2      1
# 2            2       3      2
# ...

# %%
df.columns
# Out:
# Index(['메타버스장점1', '메타버스장점2', '메타버스장점3', '메타버스극복1', '메타버스극복2', '메타버스극복3',
#        '메타버스비활성화이유', '메타버스부정적기능', '메타버스입장', 'Class'],
#       dtype='object')

# %%
z = pd.concat([df["메타버스장점1"], df["메타버스장점2"], df["메타버스장점3"]])

# %%
z =z.reset_index()

# %%
z
# Out:
#       index  0
# 0         0  1
# 1         1  4
# 2         2  2
# 3         3  1
# 4         4  1
# ...     ... ..
# 1495    495  4
# 1496    496  5
# 1497    497  3
# 1498    498  2
# 1499    499  6
#
# [1500 rows x 2 columns]
