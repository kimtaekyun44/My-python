# %%
import pandas as pd

data = {
    "변수": [
        "단말기App 서비스 + Web 서비스 추가 지원",
        "단말기App/WEB 서비스 + AR / VR 서비스 추가 지원",
        "서비스가상 박물관",
        "서비스가상 체험 박물관",
        "교육3D 아바타 가이드",
        "교육실시간 강의 및 워크샵",
        "동기부여소극적 적용",
        "동기부여적극적 적용",
        "평가방식간단한 퀴즈 및 테스트",
        "평가방식학교 교과 과정에 맞춘 사전 / 사후 평가",
        "가격"
    ],
    "Estimate": [
        0.0194, 0.9199, -0.1171, 0.0867, 0.2372, 0.1199, 0.2004, 0.4268, 0.1324, 0.2245, -0.0002
    ],
    "Std. Error": [
        0.0546, 0.0429, 0.0535, 0.0482, 0.0395, 0.0551, 0.0670, 0.0534, 0.0423, 0.0562, 0.00001
    ],
    "z-value": [
        0.3544, 21.4458, -2.1897, 1.8000, 6.0024, 2.1770, 2.9892, 7.9871, 3.1279, 3.9967, -14.4460
    ],
    "Pr(>|z|)": [
        0.723053, "< 2.2e-16", 0.028548, 0.071859, "1.944e-09", 0.029483, 0.002797, "1.332e-15", 0.001760, "6.422e-05", "< 2.2e-16"
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#                                     변수  Estimate  Std. Error  z-value  \
# 0           단말기App 서비스 + Web 서비스 추가 지원    0.0194     0.05460   0.3544
# 1   단말기App/WEB 서비스 + AR / VR 서비스 추가 지원    0.9199     0.04290  21.4458
# 2                            서비스가상 박물관   -0.1171     0.05350  -2.1897
# 3                         서비스가상 체험 박물관    0.0867     0.04820   1.8000
# 4                         교육3D 아바타 가이드    0.2372     0.03950   6.0024
# 5                       교육실시간 강의 및 워크샵    0.1199     0.05510   2.1770
# 6                           동기부여소극적 적용    0.2004     0.06700   2.9892
# 7                           동기부여적극적 적용    0.4268     0.05340   7.9871
# 8                     평가방식간단한 퀴즈 및 테스트    0.1324     0.04230   3.1279
# 9          평가방식학교 교과 과정에 맞춘 사전 / 사후 평가    0.2245     0.05620   3.9967
# 10                                  가격   -0.0002     0.00001 -14.4460
#
#      Pr(>|z|)
# 0    0.723053
# 1   < 2.2e-16
# 2    0.028548
# 3    0.071859
# 4   1.944e-09
# 5    0.029483
# 6    0.002797
# ...

# %%
df.to_clipboard()

# %%
df
# Out:
#                                     변수  Estimate  Std. Error  z-value  \
# 0           단말기App 서비스 + Web 서비스 추가 지원    0.0194     0.05460   0.3544
# 1   단말기App/WEB 서비스 + AR / VR 서비스 추가 지원    0.9199     0.04290  21.4458
# 2                            서비스가상 박물관   -0.1171     0.05350  -2.1897
# 3                         서비스가상 체험 박물관    0.0867     0.04820   1.8000
# 4                         교육3D 아바타 가이드    0.2372     0.03950   6.0024
# 5                       교육실시간 강의 및 워크샵    0.1199     0.05510   2.1770
# 6                           동기부여소극적 적용    0.2004     0.06700   2.9892
# 7                           동기부여적극적 적용    0.4268     0.05340   7.9871
# 8                     평가방식간단한 퀴즈 및 테스트    0.1324     0.04230   3.1279
# 9          평가방식학교 교과 과정에 맞춘 사전 / 사후 평가    0.2245     0.05620   3.9967
# 10                                  가격   -0.0002     0.00001 -14.4460
#
#      Pr(>|z|)
# 0    0.723053
# 1   < 2.2e-16
# 2    0.028548
# 3    0.071859
# 4   1.944e-09
# 5    0.029483
# 6    0.002797
# ...

# %%
import pandas as pd

data = {
    "변수": [
        "단말기App 서비스 + Web 서비스 추가 지원",
        "단말기App/WEB 서비스 + AR / VR 서비스 추가 지원",
        "서비스가상 박물관",
        "서비스가상 체험 박물관",
        "교육3D 아바타 가이드",
        "교육실시간 강의 및 워크샵",
        "동기부여소극적 적용",
        "동기부여적극적 적용",
        "평가방식간단한 퀴즈 및 테스트",
        "평가방식학교 교과 과정에 맞춘 사전 / 사후 평가",
        "가격"
    ],
    "Estimate": [
        0.019358, 0.91994, -0.11714, 0.086737, 0.23724, 0.11988, 0.20037, 0.42676, 0.13240, 0.22449, -0.00015413
    ],
    "Std. Error": [
        0.054625, 0.042896, 0.053496, 0.048187, 0.039524, 0.055069, 0.067032, 0.053431, 0.042328, 0.056169, 0.000010669
    ],
    "z-value": [
        0.3544, 21.4458, -2.1897, 1.8000, 6.0024, 2.1770, 2.9892, 7.9871, 3.1279, 3.9967, -14.4460
    ],
    "Pr(>|z|)": [
        round(0.723053, 8),
        "< 2.2e-16",
        round(0.028548, 8),
        round(0.071859, 8),
        round(1.944e-09, 8),
        round(0.029483, 8),
        round(0.002797, 8),
        round(1.332e-15, 8),
        round(0.00176, 8),
        round(6.422e-05, 8),
        "< 2.2e-16"
    ]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                                     변수  Estimate  Std. Error  z-value  \
# 0           단말기App 서비스 + Web 서비스 추가 지원  0.019358    0.054625   0.3544
# 1   단말기App/WEB 서비스 + AR / VR 서비스 추가 지원  0.919940    0.042896  21.4458
# 2                            서비스가상 박물관 -0.117140    0.053496  -2.1897
# 3                         서비스가상 체험 박물관  0.086737    0.048187   1.8000
# 4                         교육3D 아바타 가이드  0.237240    0.039524   6.0024
# 5                       교육실시간 강의 및 워크샵  0.119880    0.055069   2.1770
# 6                           동기부여소극적 적용  0.200370    0.067032   2.9892
# 7                           동기부여적극적 적용  0.426760    0.053431   7.9871
# 8                     평가방식간단한 퀴즈 및 테스트  0.132400    0.042328   3.1279
# 9          평가방식학교 교과 과정에 맞춘 사전 / 사후 평가  0.224490    0.056169   3.9967
# 10                                  가격 -0.000154    0.000011 -14.4460
#
#      Pr(>|z|)
# 0    0.723053
# 1   < 2.2e-16
# 2    0.028548
# 3    0.071859
# 4         0.0
# 5    0.029483
# 6    0.002797
# ...

# %%
df.to_clipboard()
